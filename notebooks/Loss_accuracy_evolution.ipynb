# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
import os

# %matplotlib inline
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-_947j0d9 because the default path (/.config/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
pwd
# Out:
# '/tf/alikou/ice-type_classification/satellite-data-pipeline/asip_v2'

# %%
epochs = [i for i in range(1,31)]

# %% [markdown]
# index=-1 : validation loss index= -3 : validation accuracy

# %%
index=-1

# %%
os.chdir("/tf/alikou/ice-type_classification/satellite-data-pipeline/asip_v2/Chosen_configs/Final_30/conf_1")
validation_loss_mse_conf_1 = []
validation_loss_mae_conf_1 = []
validation_loss_cc_conf_1 = []
validation_loss_WL_conf_1 = []

for file in glob.glob("binary*.csv"):
    print(file)
    data = np.genfromtxt(file ,delimiter=',',dtype=None, names=True)
    for i in range(data.shape[0]):
    
        Y_1= data[i][0].decode().split(';')[1:]
        Y_1 = [float(element) for element in Y_1]
        if 'mse' in file:
            validation_loss_mse_conf_1.append(Y_1[index])
        elif 'mae' in file:
            validation_loss_mae_conf_1.append(Y_1[index])
        elif 'categorical_crossentropy_epochs' in file:
            validation_loss_cc_conf_1.append(Y_1[index])
        else:
            validation_loss_WL_conf_1.append(Y_1[index])

print(len(validation_loss_cc_conf_1))

validation_loss_mse_conf_1_cont = []
validation_loss_mae_conf_1_cont = []
validation_loss_cc_conf_1_cont = []
validation_loss_WL_conf_1_cont = []

for file in glob.glob("continuous*.csv"):
    print(file)
    data = np.genfromtxt(file ,delimiter=',',dtype=None, names=True)
    
    for i in range(data.shape[0]):
    
        Y_1= data[i][0].decode().split(';')[1:]
        Y_1 = [float(element) for element in Y_1]
        
        if 'mse_epochs' in file:
            
            validation_loss_mse_conf_1_cont.append(Y_1[index])
            i+=1
        elif 'mae' in file:
            validation_loss_mae_conf_1_cont.append(Y_1[index])
        elif 'categorical_crossentropy_epochs' in file:
            validation_loss_cc_conf_1_cont.append(Y_1[index])
        else:
            validation_loss_WL_conf_1_cont.append(Y_1[index])
# Out:
# binary_chosen_20_8_0.0001_2_3_categorical_crossentropy_epochs=30_model_2_log.csv
# binary_chosen_20_8_0.0001_2_3_mse_epochs=30_model_2_log.csv
# binary_chosen_20_8_0.0001_2_3_mae_epochs=30_model_2_log.csv
# binary_chosen_20_8_0.0001_2_3_<function weighted_categorical_crossentropy.<locals>.loss at 0x7f6173068378>_epochs=30_model_2_log.csv
# 15
# continuous_chosen_20_8_0.0001_2_3_<function weighted_categorical_crossentropy.<locals>.loss at 0x7f6173068378>_epochs=30_model_2_log.csv
# continuous_chosen_20_8_0.0001_2_3_mae_epochs=30_model_2_log.csv
# continuous_chosen_20_8_0.0001_2_3_categorical_crossentropy_epochs=30_model_2_log.csv
# continuous_chosen_20_8_0.0001_2_3_mse_epochs=30_model_2_log.csv
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#   if __name__ == '__main__':
# ...

# %%
os.chdir("/tf/alikou/ice-type_classification/satellite-data-pipeline/asip_v2/Chosen_configs/Final_30/conf_2")
validation_loss_mse_conf_2 = []
validation_loss_mae_conf_2 = []
validation_loss_cc_conf_2 = []
validation_loss_WL_conf_2 = []

for file in glob.glob("binary*.csv"):
    print(file)
    data = np.genfromtxt(file ,delimiter=',',dtype=None, names=True)
    for i in range(data.shape[0]):
    
        Y_1= data[i][0].decode().split(';')[1:]
        Y_1 = [float(element) for element in Y_1]
        if 'mse' in file:
            validation_loss_mse_conf_2.append(Y_1[index])
        elif 'mae' in file:
            validation_loss_mae_conf_2.append(Y_1[index])
        elif 'categorical_crossentropy_epochs' in file:
            validation_loss_cc_conf_2.append(Y_1[index])
        else:
            validation_loss_WL_conf_2.append(Y_1[index])

validation_loss_mse_conf_2_cont = []
validation_loss_mae_conf_2_cont = []
validation_loss_cc_conf_2_cont = []
validation_loss_WL_conf_2_cont = []

for file in glob.glob("continuous*.csv"):
    print(file)
    data = np.genfromtxt(file ,delimiter=',',dtype=None, names=True)
    for i in range(data.shape[0]):
    
        Y_1= data[i][0].decode().split(';')[1:]
        Y_1 = [float(element) for element in Y_1]
        
        if 'mse' in file:
            validation_loss_mse_conf_2_cont.append(Y_1[index])
        elif 'mae' in file:
            validation_loss_mae_conf_2_cont.append(Y_1[index])
        elif 'categorical_crossentropy_epochs' in file:
            validation_loss_cc_conf_2_cont.append(Y_1[index])
        else:
            validation_loss_WL_conf_2_cont.append(Y_1[index])
# Out:
# binary_chosen_20_16_0.0001_1_3_mse_epochs=30_model_2_log.csv
# binary_chosen_20_16_0.0001_1_3_mae_epochs=30_model_2_log.csv
# binary_chosen_20_16_0.0001_1_3_<function weighted_categorical_crossentropy.<locals>.loss at 0x7f6173068378>_epochs=30_model_2_log.csv
# binary_chosen_20_16_0.0001_1_3_categorical_crossentropy_epochs=30_model_2_log.csv
# continuous_chosen_20_16_0.0001_1_3_mse_epochs=30_model_2_log.csv
# continuous_chosen_20_16_0.0001_1_3_<function weighted_categorical_crossentropy.<locals>.loss at 0x7f6173068378>_epochs=30_model_2_log.csv
# continuous_chosen_20_16_0.0001_1_3_mae_epochs=30_model_2_log.csv
# continuous_chosen_20_16_0.0001_1_3_categorical_crossentropy_epochs=30_model_2_log.csv
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#   if __name__ == '__main__':
# ...

# %%
os.chdir("/tf/alikou/ice-type_classification/satellite-data-pipeline/asip_v2/Chosen_configs/Final_30/conf_2.5")
validation_loss_mse_conf_25 = []
validation_loss_mae_conf_25 = []
validation_loss_cc_conf_25 = []
validation_loss_WL_conf_25 = []

for file in glob.glob("binary*.csv"):
    print(file)
    data = np.genfromtxt(file ,delimiter=',',dtype=None, names=True)
    for i in range(data.shape[0]):
    
        Y_1= data[i][0].decode().split(';')[1:]
        Y_1 = [float(element) for element in Y_1]
        if 'mse' in file:
            validation_loss_mse_conf_25.append(Y_1[index])
        elif 'mae' in file:
            validation_loss_mae_conf_25.append(Y_1[index])
        elif 'categorical_crossentropy_epochs=30' in file:
            validation_loss_cc_conf_25.append(Y_1[index])
        else:
            validation_loss_WL_conf_25.append(Y_1[index])

validation_loss_mse_conf_25_cont = []
validation_loss_mae_conf_25_cont = []
validation_loss_cc_conf_25_cont = []
validation_loss_WL_conf_25_cont = []

for file in glob.glob("continuous*.csv"):
    print(file)
    data = np.genfromtxt(file ,delimiter=',',dtype=None, names=True)
    for i in range(data.shape[0]):
    
        Y_1= data[i][0].decode().split(';')[1:]
        Y_1 = [float(element) for element in Y_1]
        
        if 'mse_epochs=30' in file:
            validation_loss_mse_conf_25_cont.append(Y_1[index])
        elif 'mae' in file:
            validation_loss_mae_conf_25_cont.append(Y_1[index])
        elif 'categorical_crossentropy_epochs=30' in file:
            validation_loss_cc_conf_25_cont.append(Y_1[index])
        else:
            validation_loss_WL_conf_25_cont.append(Y_1[index])
# Out:
# binary_chosen_20_16_0.0001_2_3_categorical_crossentropy_epochs=30_model_2_log.csv
# binary_chosen_20_16_0.0001_2_3_<function weighted_categorical_crossentropy.<locals>.loss at 0x7f6173068378>_epochs=30_model_2_log.csv
# binary_chosen_20_16_0.0001_2_3_mae_epochs=30_model_2_log.csv
# binary_chosen_20_16_0.0001_2_3_mse_epochs=30_model_2_log.csv
# continuous_chosen_20_16_0.0001_2_3_categorical_crossentropy_epochs=30_model_2_log.csv
# continuous_chosen_20_16_0.0001_2_3_mse_epochs=30_model_2_log.csv
# continuous_chosen_20_16_0.0001_2_3_<function weighted_categorical_crossentropy.<locals>.loss at 0x7f6173068378>_epochs=30_model_2_log.csv
# continuous_chosen_20_16_0.0001_2_3_mae_epochs=30_model_2_log.csv
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#   if __name__ == '__main__':
# ...

# %%
os.chdir("/tf/alikou/ice-type_classification/satellite-data-pipeline/asip_v2/Chosen_configs/Final_30/conf_3")
validation_loss_mse_conf_3 = []
validation_loss_mae_conf_3 = []
validation_loss_cc_conf_3 = []
validation_loss_WL_conf_3 = []

for file in glob.glob("binary*.csv"):
    print(file)
    data = np.genfromtxt(file ,delimiter=',',dtype=None, names=True)
    for i in range(data.shape[0]):
    
        Y_1= data[i][0].decode().split(';')[1:]
        Y_1 = [float(element) for element in Y_1]
        if 'mse' in file:
            validation_loss_mse_conf_3.append(Y_1[index])
        elif 'mae' in file:
            validation_loss_mae_conf_3.append(Y_1[index])
        elif 'categorical_crossentropy_epochs=30' in file:
            validation_loss_cc_conf_3.append(Y_1[index])
        else:
            validation_loss_WL_conf_3.append(Y_1[index])

validation_loss_mse_conf_3_cont = []
validation_loss_mae_conf_3_cont = []
validation_loss_cc_conf_3_cont = []
validation_loss_WL_conf_3_cont = []

for file in glob.glob("continuous*.csv"):
    print(file)
    data = np.genfromtxt(file ,delimiter=',',dtype=None, names=True)
    for i in range(data.shape[0]):
    
        Y_1= data[i][0].decode().split(';')[1:]
        Y_1 = [float(element) for element in Y_1]
        if 'mse' in file:
            validation_loss_mse_conf_3_cont.append(Y_1[index])
        elif 'mae' in file:
            validation_loss_mae_conf_3_cont.append(Y_1[index])
        elif 'categorical_crossentropy_epochs=30' in file:
            validation_loss_cc_conf_3_cont.append(Y_1[index])
        else:
            validation_loss_WL_conf_3_cont.append(Y_1[index])
# Out:
# binary_chosen_20_8_0.0001_2_4_<function weighted_categorical_crossentropy.<locals>.loss at 0x7f6173068378>_epochs=30_model_2_log.csv
# binary_chosen_20_8_0.0001_2_4_mse_epochs=30_model_2_log.csv
# binary_chosen_20_8_0.0001_2_4_mae_epochs=30_model_2_log.csv
# binary_chosen_20_8_0.0001_2_4_categorical_crossentropy_epochs=30_model_2_log.csv
# continuous_chosen_20_8_0.0001_2_4_mse_epochs=30_model_2_log.csv
# continuous_chosen_20_8_0.0001_2_4_<function weighted_categorical_crossentropy.<locals>.loss at 0x7f6173068378>_epochs=30_model_2_log.csv
# continuous_chosen_20_8_0.0001_2_4_categorical_crossentropy_epochs=30_model_2_log.csv
# continuous_chosen_20_8_0.0001_2_4_mae_epochs=30_model_2_log.csv
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#   if __name__ == '__main__':
# ...

# %%
os.chdir("/tf/alikou/ice-type_classification/satellite-data-pipeline/asip_v2/Chosen_configs/Final_30/conf_4")
validation_loss_mse_conf_4 = []
validation_loss_mae_conf_4 = []
validation_loss_cc_conf_4 = []
validation_loss_WL_conf_4 = []

for file in glob.glob("binary*.csv"):
    print(file)
    data = np.genfromtxt(file ,delimiter=',',dtype=None, names=True)
    for i in range(data.shape[0]):
    
        Y_1= data[i][0].decode().split(';')[1:]
        Y_1 = [float(element) for element in Y_1]
        if 'mse' in file:
            validation_loss_mse_conf_4.append(Y_1[index])
        elif 'mae' in file:
            validation_loss_mae_conf_4.append(Y_1[index])
        elif 'categorical_crossentropy_epochs=30' in file:
            validation_loss_cc_conf_4.append(Y_1[index])
        else:
            validation_loss_WL_conf_4.append(Y_1[index])

validation_loss_mse_conf_4_cont = []
validation_loss_mae_conf_4_cont = []
validation_loss_cc_conf_4_cont = []
validation_loss_WL_conf_4_cont = []

for file in glob.glob("continuous*.csv"):
    print(file)
    data = np.genfromtxt(file ,delimiter=',',dtype=None, names=True)
    for i in range(data.shape[0]):
    
        Y_1= data[i][0].decode().split(';')[1:]
        Y_1 = [float(element) for element in Y_1]
        if 'mse' in file:
            validation_loss_mse_conf_4_cont.append(Y_1[index])
        elif 'mae' in file:
            validation_loss_mae_conf_4_cont.append(Y_1[index])
        elif 'categorical_crossentropy_epochs=30' in file:
            validation_loss_cc_conf_4_cont.append(Y_1[index])
        else:
            validation_loss_WL_conf_4_cont.append(Y_1[index])
# Out:
# binary_chosen_20_16_0.0001_2_4_mse_epochs=30_model_2_log.csv
# binary_chosen_20_16_0.0001_2_4_categorical_crossentropy_epochs=30_model_2_log.csv
# binary_chosen_20_16_0.0001_2_4_<function weighted_categorical_crossentropy.<locals>.loss at 0x7f6173068378>_epochs=30_model_2_log.csv
# binary_chosen_20_16_0.0001_2_4_mae_epochs=30_model_2_log.csv
# continuous_chosen_20_16_0.0001_2_4_categorical_crossentropy_epochs=30_model_2_log.csv
# continuous_chosen_20_16_0.0001_2_4_mae_epochs=30_model_2_log.csv
# continuous_chosen_20_16_0.0001_2_4_<function weighted_categorical_crossentropy.<locals>.loss at 0x7f6173068378>_epochs=30_model_2_log.csv
# continuous_chosen_20_16_0.0001_2_4_mse_epochs=30_model_2_log.csv
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#   if __name__ == '__main__':
# ...

# %%
fig, axs = plt.subplots(4, 2, figsize=(15,15))
fig.tight_layout(pad=3.0)

axs[0, 0].semilogy(epochs[:len(validation_loss_mse_conf_1)], validation_loss_mse_conf_1,  c='y',marker = 'o',alpha=0.5, label='Conf_1 : 3_2_8')
axs[0, 0].semilogy(epochs[:len(validation_loss_mse_conf_2)], validation_loss_mse_conf_2, c='green',alpha=0.5,marker='o',label='Conf_2 : 3_1_16')
axs[0, 0].semilogy(epochs[:len(validation_loss_mse_conf_25)], validation_loss_mse_conf_25, c='r',alpha=0.5,marker='X',label='Conf_2.5 : 3_2_16')
axs[0, 0].semilogy(epochs[:len(validation_loss_mse_conf_3)], validation_loss_mse_conf_3, alpha=0.5, c='purple',marker = 'o',label='Conf_3 : 4_2_8')
axs[0, 0].semilogy(epochs[:len(validation_loss_mse_conf_4)], validation_loss_mse_conf_4, alpha=0.5, c='blue',marker = 'X',label='Conf_4 : 4_2_16')
axs[0,0].set_ylim([0.5,0.8])
axs[0, 0].set_title('MSE binary')

axs[0, 1].semilogy(epochs[:len(validation_loss_mse_conf_1_cont)], validation_loss_mse_conf_1_cont, alpha=0.5, c='y',marker = 'o')
axs[0, 1].semilogy(epochs[:len(validation_loss_mse_conf_2_cont)], validation_loss_mse_conf_2_cont, alpha=0.5, c='green',marker='o')
axs[0, 1].semilogy(epochs[:len(validation_loss_mse_conf_25_cont)], validation_loss_mse_conf_25_cont, alpha=0.5, c='r',marker='X')
axs[0, 1].semilogy(epochs[:len(validation_loss_mse_conf_3_cont)], validation_loss_mse_conf_3_cont, alpha=0.5, c='purple',marker = 'o')
axs[0, 1].semilogy(epochs[:len(validation_loss_mse_conf_4_cont)], validation_loss_mse_conf_4_cont, alpha=0.5, c='blue',marker = 'X')
axs[0, 1].set_ylim([0.5,0.8])
axs[0, 1].set_title('MSE continuous')

axs[1, 0].semilogy(epochs[:len(validation_loss_mae_conf_1)], validation_loss_mae_conf_1, alpha=0.5, c='y',marker = 'o')
axs[1, 0].semilogy(epochs[:len(validation_loss_mae_conf_2)], validation_loss_mae_conf_2, alpha=0.5, c='green',marker='o')
axs[1, 0].semilogy(epochs[:len(validation_loss_mae_conf_25)], validation_loss_mae_conf_25, alpha=0.5, c='r',marker='X')
axs[1, 0].semilogy(epochs[:len(validation_loss_mae_conf_3)], validation_loss_mae_conf_3, alpha=0.5, c='purple',marker = 'o')
axs[1, 0].semilogy(epochs[:len(validation_loss_mae_conf_4)], validation_loss_mae_conf_4, alpha=0.5, c='blue',marker = 'X')
axs[1, 0].set_ylim([0.3,0.8])
axs[1, 0].set_title('MAE binary')

axs[1, 1].semilogy(epochs[:len(validation_loss_mae_conf_1_cont)], validation_loss_mae_conf_1_cont, alpha=0.5, c='y',marker = 'o')
axs[1, 1].semilogy(epochs[:len(validation_loss_mae_conf_2_cont)], validation_loss_mae_conf_2_cont, alpha=0.5, c='green',marker='o')
axs[1, 1].semilogy(epochs[:len(validation_loss_mae_conf_25_cont)], validation_loss_mae_conf_25_cont, alpha=0.5, c='r',marker='X')
axs[1, 1].semilogy(epochs[:len(validation_loss_mae_conf_3_cont)], validation_loss_mae_conf_3_cont, alpha=0.5, c='purple',marker = 'o')
axs[1, 1].semilogy(epochs[:len(validation_loss_mae_conf_4_cont)], validation_loss_mae_conf_4_cont, alpha=0.5, c='blue',marker = 'X')
axs[1, 1].set_ylim([0.3,0.8])
axs[1, 1].set_title('MAE continuous')

print(len(validation_loss_cc_conf_1))
axs[2, 0].semilogy(epochs[:len(validation_loss_cc_conf_1)], validation_loss_cc_conf_1, alpha=0.5, c='y',marker = 'o')
axs[2, 0].semilogy(epochs[:len(validation_loss_cc_conf_2)], validation_loss_cc_conf_2, alpha=0.5, c='green',marker='o')
axs[2, 0].semilogy(epochs[:len(validation_loss_cc_conf_25)], validation_loss_cc_conf_25, alpha=0.5, c='r',marker='X')
axs[2, 0].semilogy(epochs[:len(validation_loss_cc_conf_3)], validation_loss_cc_conf_3, alpha=0.5, c='purple',marker = 'o')
axs[2, 0].semilogy(epochs[:len(validation_loss_cc_conf_4)], validation_loss_cc_conf_4, alpha=0.5, c='blue',marker = 'X')
axs[2, 0].set_ylim([0.65,0.8])
axs[2, 0].set_title('CC binary')

axs[2, 1].semilogy(epochs[:len(validation_loss_cc_conf_1_cont)], validation_loss_cc_conf_1_cont, alpha=0.5, c='y',marker = 'o')
axs[2, 1].semilogy(epochs[:len(validation_loss_cc_conf_2_cont)], validation_loss_cc_conf_2_cont, alpha=0.5, c='green',marker='o')
axs[2, 1].semilogy(epochs[:len(validation_loss_cc_conf_25_cont)], validation_loss_cc_conf_25_cont, alpha=0.5, c='r',marker='X')
axs[2, 1].semilogy(epochs[:len(validation_loss_cc_conf_3_cont)], validation_loss_cc_conf_3_cont, alpha=0.5, c='purple',marker = 'o')
axs[2, 1].semilogy(epochs[:len(validation_loss_cc_conf_4_cont)], validation_loss_cc_conf_4_cont, alpha=0.5, c='blue',marker = 'X')
axs[2, 1].set_ylim([0.65,0.8])
axs[2, 1].set_title('CC continuous')

axs[3, 0].semilogy(epochs[:len(validation_loss_WL_conf_1)], validation_loss_WL_conf_1, alpha=0.5, c='y',marker = 'o')
axs[3, 0].semilogy(epochs[:len(validation_loss_WL_conf_2)], validation_loss_WL_conf_2, alpha=0.5, c='green',marker='o')
axs[3, 0].semilogy(epochs[:len(validation_loss_WL_conf_25)], validation_loss_WL_conf_25, alpha=0.5, c='r',marker='X')
axs[3, 0].semilogy(epochs[:len(validation_loss_WL_conf_3)], validation_loss_WL_conf_3, alpha=0.5, c='purple',marker = 'o')
axs[3, 0].semilogy(epochs[:len(validation_loss_WL_conf_4)], validation_loss_WL_conf_4, alpha=0.5, c='blue',marker = 'X')
axs[3, 0].set_ylim([0.3,0.8])
axs[3, 0].set_title('WL binary')

axs[3, 1].semilogy(epochs[:len(validation_loss_WL_conf_1_cont)], validation_loss_WL_conf_1_cont, alpha=0.5, c='y',marker = 'o')
axs[3, 1].semilogy(epochs[:len(validation_loss_WL_conf_2_cont)], validation_loss_WL_conf_2_cont, alpha=0.5, c='green',marker='o')
axs[3, 1].semilogy(epochs[:len(validation_loss_WL_conf_25_cont)], validation_loss_WL_conf_25_cont, alpha=0.5, c='r',marker='X')
axs[3, 1].semilogy(epochs[:len(validation_loss_WL_conf_3_cont)], validation_loss_WL_conf_3_cont, alpha=0.5, c='purple',marker = 'o')
axs[3, 1].semilogy(epochs[:len(validation_loss_WL_conf_4_cont)], validation_loss_WL_conf_4_cont, alpha=0.5, c='blue',marker = 'X')
axs[3, 1].set_ylim([0.3,0.8])
axs[3, 1].set_title('WL continuous')



fig.legend(loc='upper right')

plt.show()
# Out:
# 15
