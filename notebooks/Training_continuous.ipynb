# %%
import argparse
import datetime
import os
from os.path import basename, dirname, join

import glob

import numpy as np
import tensorflow as tf
tf.config.set_visible_devices([], 'GPU')
import matplotlib.pyplot as plt
import random

from tensorflow.keras.layers.experimental.preprocessing import Resizing 
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

from archive import Archive
from data_generator import DataGeneratorFrom_npz_File, DataGenerator
from utility import Configure, between_zero_and_one_float_type
from train_model import FileBasedConfigure

from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *

from netCDF4 import Dataset
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-olfc6rdu because the default path (/.config/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
def weighted_categorical_crossentropy(weights):
    """
    A weighted version of keras.objectives.categorical_crossentropy
    
    Variables:
        weights: numpy array of shape (C,) where C is the number of classes
    
    Usage:
        weights = np.array([0.5,2,10]) # Class one at 0.5, class 2 twice the normal weights, class 3 10x.
        loss = weighted_categorical_crossentropy(weights)
        model.compile(loss=loss,optimizer='adam')
    """
    
    weigths = tf.expand_dims(tf.Variable(weights, dtype=tf.float32), axis=0)
    weigths = tf.expand_dims(weights, axis=0)
    
    def loss(y_true, y_pred):
        # scale predictions so that the class probas of each sample sum to 1
        y_pred /= tf.reduce_sum(y_pred, axis=-1, keepdims=True)
        # clip to prevent NaN's and Inf's
        y_pred = tf.clip_by_value(y_pred, tf.keras.backend.epsilon(), 1 - tf.keras.backend.epsilon())
        # calc
        loss = y_true * tf.math.log(y_pred) * weights
        loss = -tf.reduce_sum(loss, -1)
        return loss
    
    return loss

# %%
class_weight = np.array([0.5, 1, 0.7, 0.8])

weights = np.expand_dims(class_weight/np.sum(class_weight),axis=0)

weighted_loss = weighted_categorical_crossentropy(weights)

# %%
idir = '/input_data/exp_data/continuous_output'
train_ratio = 0.8
npz_files = sorted(glob.glob(f'{idir}/*npz'))
random.shuffle(npz_files)
train_files_number = int(len(npz_files) * train_ratio)
train_files = npz_files[:train_files_number]
valid_files = npz_files[train_files_number:]

input_var_names = ['nersc_sar_primary', 'nersc_sar_secondary']
amsr2_var_names = [
    'btemp_6_9h',
    'btemp_6_9v',
    'btemp_7_3h',
    'btemp_7_3v',
    'btemp_10_7h',
    'btemp_10_7v',
    'btemp_18_7h',
    'btemp_18_7v',
    'btemp_23_8h',
    'btemp_23_8v',
    'btemp_36_5h',
    'btemp_36_5v',
    'btemp_89_0h',
    'btemp_89_0v',
 ]
output_var_name = 'ice_type'

dims_input = np.load(npz_files[0])[input_var_names[0]].shape
dims_output = np.load(npz_files[0])[output_var_name].shape
dims_amsr2 = np.load(npz_files[0])[amsr2_var_names[0]].shape



batch_size_list = [20,40,80]
list_filters = [8, 16, 32]
learning_rate = [1e-3, 1e-4, 1e-5]
conv_number = [1,2]
unet_depth = [3,4]
losses = ['mse', 'mae', 'categorical_crossentropy', weighted_loss]

from keras.callbacks import CSVLogger

csv_logger = CSVLogger('log.csv', append=True, separator=';')
val_loss_cb = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)

# %%
def train_val_generator(batch_size):
    params = {'dims_input':      (*dims_input, len(input_var_names)),
                       'dims_output':     (*dims_output,),
                       'dims_amsr2':      (*dims_amsr2, len(amsr2_var_names)),
                       'output_var_name': output_var_name,
                       'input_var_names': input_var_names,
                       'amsr2_var_names': amsr2_var_names,
                       'batch_size':      batch_size,
                       'shuffle_on_epoch_end': False,
                       }
    input_size = params['dims_input']
    amsr2_size = params['dims_amsr2']


    training_generator = DataGeneratorFrom_npz_File(train_files, **params)
    validation_generator = DataGeneratorFrom_npz_File(valid_files, **params)

    return validation_generator, training_generator, input_size, amsr2_size

# %%
params_list = []
for i in range(len(losses)):
    
    combination = [batch_size_list[0], list_filters[0], learning_rate[1], conv_number[1], unet_depth[0], losses[3]]
    params_list.append(combination)
    combination = [batch_size_list[0], list_filters[1], learning_rate[1], conv_number[0], unet_depth[0], losses[3]]
    params_list.append(combination)
    
    
params_list
# Out:
# [[20,
#   8,
#   0.0001,
#   2,
#   3,
#   <function __main__.weighted_categorical_crossentropy.<locals>.loss(y_true, y_pred)>],
#  [20,
#   16,
#   0.0001,
#   1,
#   3,
#   <function __main__.weighted_categorical_crossentropy.<locals>.loss(y_true, y_pred)>],
#  [20,
#   8,
#   0.0001,
#   2,
#   3,
#   <function __main__.weighted_categorical_crossentropy.<locals>.loss(y_true, y_pred)>],
#  [20,
#   16,
#   0.0001,
#   1,
#   3,
#   <function __main__.weighted_categorical_crossentropy.<locals>.loss(y_true, y_pred)>],
#  [20,
#   8,
#   0.0001,
#   2,
#   3,
#   <function __main__.weighted_categorical_crossentropy.<locals>.loss(y_true, y_pred)>],
#  [20,
#   16,
#   0.0001,
#   1,
#   3,
#   <function __main__.weighted_categorical_crossentropy.<locals>.loss(y_true, y_pred)>],
#  [20,
#   8,
#   0.0001,
#   2,
#   3,
#   <function __main__.weighted_categorical_crossentropy.<locals>.loss(y_true, y_pred)>],
#  [20,
#   16,
#   0.0001,
#   1,
#   3,
#   <function __main__.weighted_categorical_crossentropy.<locals>.loss(y_true, y_pred)>]]

# %% [markdown]
# # U-net DEPTH = 3

# %%
# U-net DEPTH = 3
for batch_size, n_filters, rate, cnumber, depth, loss_ in params_list:
    params = {'dims_input':      (*dims_input, len(input_var_names)),
           'dims_output':     (*dims_output,),
           'dims_amsr2':      (*dims_amsr2, len(amsr2_var_names)),
           'output_var_name': output_var_name,
           'input_var_names': input_var_names,
           'amsr2_var_names': amsr2_var_names,
           'batch_size':      batch_size,
           'shuffle_on_epoch_end': False,
           }


    training_generator = train_val_generator(batch_size)[0]
    validation_generator = train_val_generator(batch_size)[1]
    input_size = train_val_generator(batch_size)[2]
    amsr2_size = train_val_generator(batch_size)[3]

    
    inputs = layers.Input(shape=input_size)
    
    inputs_2 = layers.Input(shape=amsr2_size)

    conv2 = layers.Conv2D(n_filters, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(inputs)
    if cnumber ==2:
        conv2 = layers.Conv2D(n_filters, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv2)

    pool2 = layers.MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = layers.Conv2D(2*n_filters, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    if cnumber ==2:
        conv3 = layers.Conv2D(2*n_filters, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)

    pool3 = layers.MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = layers.Conv2D(4*n_filters, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    if cnumber ==2:
        conv4 = layers.Conv2D(4*n_filters, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)

    

    pool4 = layers.MaxPooling2D(pool_size=(2, 2))(conv4)

    amsr2_up = Resizing(32,32)(inputs_2)

    pool4 = layers.Concatenate(axis = 3)([pool4 , amsr2_up])

    conv5 = layers.Conv2D(8*n_filters, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
    if cnumber ==2:
        conv5 = layers.Conv2D(8*n_filters, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)

    


    up6 = layers.Conv2D(4*n_filters, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(layers.UpSampling2D(size = (2,2))(conv5))

    merge6 = layers.Concatenate(axis = 3)([conv4,up6])

    conv6 = layers.Conv2D(4*n_filters, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    if cnumber ==2:
        conv6 = layers.Conv2D(4*n_filters, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)

    up7 = layers.Conv2D(2*n_filters, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(layers.UpSampling2D(size = (2,2))(conv6))

    merge7 = layers.Concatenate(axis = 3)([conv3,up7])

    conv7 = layers.Conv2D(2*n_filters, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    if cnumber ==2:
        conv7 = layers.Conv2D(2*n_filters, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)

    up8 = layers.Conv2D(n_filters, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(layers.UpSampling2D(size = (2,2))(conv7))

    merge8 = layers.Concatenate(axis = 3)([conv2,up8])

    conv8 = layers.Conv2D(n_filters, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    if cnumber ==2:
        conv8 = layers.Conv2D(n_filters, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)

    conv10 = layers.Conv2D(3, 1, activation = 'softmax')(conv8)


    model = Model(inputs = [inputs, inputs_2], outputs = conv10)

    model.compile(optimizer = Adam(learning_rate=1e-4), loss = loss_, metrics = ['accuracy', 'categorical_accuracy'])
    model.summary()
    csv_logger = CSVLogger('continuous_chosen_'+str(20)+'_'+str(n_filters)+'_'+ str(1e-4)+'_'+str(cnumber)+'_'+ str(depth)+'_'+str(loss_)+'_epochs=15'+'_'+'_model_2_log.csv', append=True, separator=';')
    model.fit(training_generator, validation_data = validation_generator, epochs = 15,callbacks= [csv_logger, val_loss_cb])

    model.save('continuous_chosen_'+str(20)+'_'+str(n_filters)+'_'+ str(1e-4)+'_'+str(cnumber)+'_'+ str(depth)+'_'+str(loss_)+'_epochs=15'+'_'+'_model_2')
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 256, 256, 2) 0
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 256, 256, 8)  152         input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 256, 256, 8)  584         conv2d_18[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 128, 128, 8)  0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 128, 128, 16) 1168        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 128, 128, 16) 2320        conv2d_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 64, 64, 16)   0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 64, 64, 32)   4640        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 64, 64, 32)   9248        conv2d_22[0][0]
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 16, 16, 14)] 0
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 32, 32, 32)   0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# resizing_1 (Resizing)           (None, 32, 32, 14)   0           input_4[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 46)   0           max_pooling2d_5[0][0]
#                                                                  resizing_1[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 32, 32, 64)   26560       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 32, 32, 64)   36928       conv2d_24[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 64, 64, 64)   0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 64, 64, 32)   8224        up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 64)   0           conv2d_23[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 64, 64, 32)   18464       concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 64, 64, 32)   9248        conv2d_27[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 128, 128, 32) 0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 128, 128, 16) 2064        up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128, 128, 32) 0           conv2d_21[0][0]
#                                                                  conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 128, 128, 16) 4624        concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 128, 128, 16) 2320        conv2d_30[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 256, 256, 16) 0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 256, 256, 8)  520         up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 256, 256, 16) 0           conv2d_19[0][0]
#                                                                  conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 256, 256, 8)  1160        concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 256, 256, 8)  584         conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 256, 256, 3)  27          conv2d_34[0][0]
# ==================================================================================================
# Total params: 128,835
# Trainable params: 128,835
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/15
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-8-033e00e6bb25> in <module>
#     102     model.summary()
#     103     csv_logger = CSVLogger('continuous_chosen_'+str(20)+'_'+str(n_filters)+'_'+ str(1e-4)+'_'+str(cnumber)+'_'+ str(depth)+'_'+str(loss_)+'_epochs=15'+'_'+'_model_2_log.csv', append=True, separator=';')
# --> 104     model.fit(training_generator, validation_data = validation_generator, epochs = 15,callbacks= [csv_logger, val_loss_cb])
#     105 #     classes_model2 = model.predict(test_dataset)
#     106     model.save('continuous_chosen_'+str(20)+'_'+str(n_filters)+'_'+ str(1e-4)+'_'+str(cnumber)+'_'+ str(depth)+'_'+str(loss_)+'_epochs=15'+'_'+'_model_2')
#
# ~usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1181                 _r=1):
#    1182               callbacks.on_train_batch_begin(step)
# -> 1183               tmp_logs = self.train_function(iterator)
#    1184               if data_handler.should_sync:
#    1185                 context.async_wait()
#
# ~usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     887
#     888       with OptionalXlaContext(self._jit_compile):
# --> 889         result = self._call(*args, **kwds)
#     890
#     891       new_tracing_count = self.experimental_get_tracing_count()
#
# ~usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     931       # This is the first call of __call__, so we have to initialize.
#     932       initializers = []
# --> 933       self._initialize(args, kwds, add_initializers_to=initializers)
#     934     finally:
#     935       # At this point we know that the initialization is complete (or less
#
# ~usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     762     self._concrete_stateful_fn = (
#     763         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
# --> 764             *args, **kwds))
#     765
#     766     def invalid_creator_scope(*unused_args, **unused_kwds):
#
# ~usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    3048       args, kwargs = None, None
#    3049     with self._lock:
# -> 3050       graph_function, _ = self._maybe_define_function(args, kwargs)
#    3051     return graph_function
#    3052
#
# ~usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3442
#    3443           self._function_cache.missed.add(call_context_key)
# -> 3444           graph_function = self._create_graph_function(args, kwargs)
#    3445           self._function_cache.primary[cache_key] = graph_function
#    3446
#
# ~usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3287             arg_names=arg_names,
#    3288             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3289             capture_by_value=self._capture_by_value),
#    3290         self._function_attributes,
#    3291         function_spec=self.function_spec,
#
# ~usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     997         _, original_func = tf_decorator.unwrap(python_func)
#     998
# --> 999       func_outputs = python_func(*func_args, **func_kwargs)
#    1000
#    1001       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     670         # the function a weak reference to itself to avoid a reference cycle.
#     671         with OptionalXlaContext(compile_with_xla):
# --> 672           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     673         return out
#     674
#
# ~usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     984           except Exception as e:  # pylint:disable=broad-except
#     985             if hasattr(e, "ag_error_metadata"):
# --> 986               raise e.ag_error_metadata.to_exception(e)
#     987             else:
#     988               raise
#
# NotImplementedError: in user code:
#
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:855 train_function  *
#         return step_function(self, iterator)
#     <ipython-input-2-f4b1c7040f4c>:23 loss  *
#         loss = y_true * tf.math.log(y_pred) * weights
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:1245 binary_op_wrapper
#         out = r_op(x)
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py:870 __array__
#         " a NumPy call, which is not supported".format(self.name))
#
#     NotImplementedError: Cannot convert a symbolic Tensor (loss/mul:0) to a numpy array. This error may indicate that you're trying to pass a Tensor to a NumPy call, which is not supported

# %% [markdown]
# ####

# %%
params_list = []
for i in range(len(losses)):
    
    combination = [batch_size_list[0], list_filters[0], learning_rate[1], conv_number[1], unet_depth[1], losses[i]]
    params_list.append(combination)
    
    
    
params_list
# Out:
# [[20, 8, 0.0001, 2, 4, 'mse'],
#  [20, 8, 0.0001, 2, 4, 'mae'],
#  [20, 8, 0.0001, 2, 4, 'categorical_crossentropy'],
#  [20,
#   8,
#   0.0001,
#   2,
#   4,
#   <function __main__.weighted_categorical_crossentropy.<locals>.loss(y_true, y_pred)>]]

# %% [markdown]
# # U-net DEPTH = 4

# %%
# U-net DEPTH = 4
for batch_size, n_filters, rate, cnumber, depth, loss_ in params_list:
    params = {'dims_input':      (*dims_input, len(input_var_names)),
           'dims_output':     (*dims_output,),
           'dims_amsr2':      (*dims_amsr2, len(amsr2_var_names)),
           'output_var_name': output_var_name,
           'input_var_names': input_var_names,
           'amsr2_var_names': amsr2_var_names,
           'batch_size':      batch_size,
           'shuffle_on_epoch_end': False,
           }


    training_generator = train_val_generator(batch_size)[0]
    validation_generator = train_val_generator(batch_size)[1]
    input_size = train_val_generator(batch_size)[2]
    amsr2_size = train_val_generator(batch_size)[3]

    
    inputs = layers.Input(shape=input_size)
    
    inputs_2 = layers.Input(shape=amsr2_size)

    conv1 = layers.Conv2D(n_filters, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(inputs)
    if cnumber ==2:
        conv1 = layers.Conv2D(n_filters, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv1)

    pool1 = layers.MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = layers.Conv2D(2*n_filters, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool1)
    if cnumber ==2:
        conv2 = layers.Conv2D(2*n_filters, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv2)

    pool2 = layers.MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = layers.Conv2D(4*n_filters, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    if cnumber ==2:
        conv3 = layers.Conv2D(4*n_filters, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)

    pool3 = layers.MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = layers.Conv2D(8*n_filters, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    if cnumber ==2:
        conv4 = layers.Conv2D(8*n_filters, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)

    

    pool4 = layers.MaxPooling2D(pool_size=(2, 2))(conv4)


    pool4 = layers.Concatenate(axis = 3)([pool4 , inputs_2])

    conv5 = layers.Conv2D(16*n_filters, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
    if cnumber ==2:
        conv5 = layers.Conv2D(16*n_filters, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)

    


    up6 = layers.Conv2D(8*n_filters, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(layers.UpSampling2D(size = (2,2))(conv5))

    merge6 = layers.Concatenate(axis = 3)([conv4,up6])

    conv6 = layers.Conv2D(8*n_filters, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    if cnumber ==2:
        conv6 = layers.Conv2D(8*n_filters, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)

    up7 = layers.Conv2D(4*n_filters, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(layers.UpSampling2D(size = (2,2))(conv6))

    merge7 = layers.Concatenate(axis = 3)([conv3,up7])

    conv7 = layers.Conv2D(4*n_filters, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    if cnumber ==2:
        conv7 = layers.Conv2D(4*n_filters, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)

    up8 = layers.Conv2D(2*n_filters, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(layers.UpSampling2D(size = (2,2))(conv7))

    merge8 = layers.Concatenate(axis = 3)([conv2,up8])

    conv8 = layers.Conv2D(2*n_filters, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    if cnumber ==2:
        conv8 = layers.Conv2D(2*n_filters, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)

    up9 = layers.Conv2D(n_filters, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(layers.UpSampling2D(size = (2,2))(conv8))

    merge9 = layers.Concatenate(axis = 3)([conv1,up9])

    conv9 = layers.Conv2D(n_filters, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    if cnumber ==2:
        conv9 = layers.Conv2D(n_filters, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)

    conv9 = layers.Conv2D(4, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)

    conv10 = layers.Conv2D(4, 1, activation = 'softmax')(conv9)



    model = Model(inputs = [inputs, inputs_2], outputs = conv10)

    model.compile(optimizer = Adam(learning_rate=1e-4), loss = loss_, metrics = ['accuracy','categorical_accuracy'])
    model.summary()
    csv_logger = CSVLogger('continuous_chosen_'+str(20)+'_'+str(n_filters)+'_'+ str(1e-4)+'_'+str(cnumber)+'_'+ str(depth)+'_'+str(loss_)+'_epochs=15'+'_'+'_model_2_log.csv', append=True, separator=';')
    model.fit(training_generator, validation_data = validation_generator, epochs = 15,callbacks= [csv_logger, val_loss_cb])

    model.save('continuous_chosen_'+str(20)+'_'+str(n_filters)+'_'+ str(1e-4)+'_'+str(cnumber)+'_'+ str(depth)+'_'+str(loss_)+'_epochs=15'+'_'+'_model_2')
# Out:
# Model: "model_9"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_19 (InputLayer)           [(None, 256, 256, 2) 0
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 256, 256, 8)  152         input_19[0][0]
# __________________________________________________________________________________________________
# conv2d_135 (Conv2D)             (None, 256, 256, 8)  584         conv2d_134[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_27 (MaxPooling2D) (None, 128, 128, 8)  0           conv2d_135[0][0]
# __________________________________________________________________________________________________
# conv2d_136 (Conv2D)             (None, 128, 128, 16) 1168        max_pooling2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_137 (Conv2D)             (None, 128, 128, 16) 2320        conv2d_136[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_28 (MaxPooling2D) (None, 64, 64, 16)   0           conv2d_137[0][0]
# __________________________________________________________________________________________________
# conv2d_138 (Conv2D)             (None, 64, 64, 32)   4640        max_pooling2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 64, 64, 32)   9248        conv2d_138[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_29 (MaxPooling2D) (None, 32, 32, 32)   0           conv2d_139[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 32, 32, 64)   18496       max_pooling2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 32, 32, 64)   36928       conv2d_140[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_30 (MaxPooling2D) (None, 16, 16, 64)   0           conv2d_141[0][0]
# __________________________________________________________________________________________________
# input_20 (InputLayer)           [(None, 16, 16, 14)] 0
# __________________________________________________________________________________________________
# concatenate_36 (Concatenate)    (None, 16, 16, 78)   0           max_pooling2d_30[0][0]
#                                                                  input_20[0][0]
# __________________________________________________________________________________________________
# conv2d_142 (Conv2D)             (None, 16, 16, 128)  89984       concatenate_36[0][0]
# __________________________________________________________________________________________________
# conv2d_143 (Conv2D)             (None, 16, 16, 128)  147584      conv2d_142[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_27 (UpSampling2D) (None, 32, 32, 128)  0           conv2d_143[0][0]
# __________________________________________________________________________________________________
# conv2d_144 (Conv2D)             (None, 32, 32, 64)   32832       up_sampling2d_27[0][0]
# __________________________________________________________________________________________________
# concatenate_37 (Concatenate)    (None, 32, 32, 128)  0           conv2d_141[0][0]
#                                                                  conv2d_144[0][0]
# __________________________________________________________________________________________________
# conv2d_145 (Conv2D)             (None, 32, 32, 64)   73792       concatenate_37[0][0]
# __________________________________________________________________________________________________
# conv2d_146 (Conv2D)             (None, 32, 32, 64)   36928       conv2d_145[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_28 (UpSampling2D) (None, 64, 64, 64)   0           conv2d_146[0][0]
# __________________________________________________________________________________________________
# conv2d_147 (Conv2D)             (None, 64, 64, 32)   8224        up_sampling2d_28[0][0]
# __________________________________________________________________________________________________
# concatenate_38 (Concatenate)    (None, 64, 64, 64)   0           conv2d_139[0][0]
#                                                                  conv2d_147[0][0]
# __________________________________________________________________________________________________
# conv2d_148 (Conv2D)             (None, 64, 64, 32)   18464       concatenate_38[0][0]
# __________________________________________________________________________________________________
# conv2d_149 (Conv2D)             (None, 64, 64, 32)   9248        conv2d_148[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_29 (UpSampling2D) (None, 128, 128, 32) 0           conv2d_149[0][0]
# __________________________________________________________________________________________________
# conv2d_150 (Conv2D)             (None, 128, 128, 16) 2064        up_sampling2d_29[0][0]
# __________________________________________________________________________________________________
# concatenate_39 (Concatenate)    (None, 128, 128, 32) 0           conv2d_137[0][0]
#                                                                  conv2d_150[0][0]
# __________________________________________________________________________________________________
# conv2d_151 (Conv2D)             (None, 128, 128, 16) 4624        concatenate_39[0][0]
# __________________________________________________________________________________________________
# conv2d_152 (Conv2D)             (None, 128, 128, 16) 2320        conv2d_151[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_30 (UpSampling2D) (None, 256, 256, 16) 0           conv2d_152[0][0]
# __________________________________________________________________________________________________
# conv2d_153 (Conv2D)             (None, 256, 256, 8)  520         up_sampling2d_30[0][0]
# __________________________________________________________________________________________________
# concatenate_40 (Concatenate)    (None, 256, 256, 16) 0           conv2d_135[0][0]
#                                                                  conv2d_153[0][0]
# __________________________________________________________________________________________________
# conv2d_154 (Conv2D)             (None, 256, 256, 8)  1160        concatenate_40[0][0]
# __________________________________________________________________________________________________
# conv2d_155 (Conv2D)             (None, 256, 256, 8)  584         conv2d_154[0][0]
# __________________________________________________________________________________________________
# conv2d_156 (Conv2D)             (None, 256, 256, 4)  292         conv2d_155[0][0]
# __________________________________________________________________________________________________
# conv2d_157 (Conv2D)             (None, 256, 256, 4)  20          conv2d_156[0][0]
# ==================================================================================================
# Total params: 502,176
# Trainable params: 502,176
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/15
# 20/20 [==============================] - 98s 5s/step - loss: 0.2148 - accuracy: 0.4463 - categorical_accuracy: 0.4463 - val_loss: 0.1678 - val_accuracy: 0.4711 - val_categorical_accuracy: 0.4711
# Epoch 2/15
# 20/20 [==============================] - 98s 5s/step - loss: 0.1162 - accuracy: 0.6313 - categorical_accuracy: 0.6313 - val_loss: 0.0976 - val_accuracy: 0.6981 - val_categorical_accuracy: 0.6981
# Epoch 3/15
# 20/20 [==============================] - 92s 5s/step - loss: 0.0886 - accuracy: 0.7211 - categorical_accuracy: 0.7211 - val_loss: 0.0844 - val_accuracy: 0.7388 - val_categorical_accuracy: 0.7388
# Epoch 4/15
# 20/20 [==============================] - 97s 5s/step - loss: 0.0840 - accuracy: 0.7349 - categorical_accuracy: 0.7349 - val_loss: 0.0836 - val_accuracy: 0.7501 - val_categorical_accuracy: 0.7501
# Epoch 5/15
# 20/20 [==============================] - 94s 5s/step - loss: 0.0805 - accuracy: 0.7535 - categorical_accuracy: 0.7535 - val_loss: 0.0819 - val_accuracy: 0.7398 - val_categorical_accuracy: 0.7398
# Epoch 6/15
# 20/20 [==============================] - 96s 5s/step - loss: 0.0768 - accuracy: 0.7594 - categorical_accuracy: 0.7594 - val_loss: 0.0741 - val_accuracy: 0.7736 - val_categorical_accuracy: 0.7736
# Epoch 7/15
# 20/20 [==============================] - 90s 5s/step - loss: 0.0747 - accuracy: 0.7656 - categorical_accuracy: 0.7656 - val_loss: 0.0733 - val_accuracy: 0.7715 - val_categorical_accuracy: 0.7715
# Epoch 8/15
# 20/20 [==============================] - 92s 5s/step - loss: 0.0735 - accuracy: 0.7626 - categorical_accuracy: 0.7626 - val_loss: 0.0712 - val_accuracy: 0.7797 - val_categorical_accuracy: 0.7797
# Epoch 9/15
# 20/20 [==============================] - 101s 5s/step - loss: 0.0672 - accuracy: 0.7766 - categorical_accuracy: 0.7766 - val_loss: 0.0634 - val_accuracy: 0.7730 - val_categorical_accuracy: 0.7730
# Epoch 10/15
# 20/20 [==============================] - 96s 5s/step - loss: 0.0584 - accuracy: 0.7783 - categorical_accuracy: 0.7783 - val_loss: 0.0525 - val_accuracy: 0.7714 - val_categorical_accuracy: 0.7714
# Epoch 11/15
# 20/20 [==============================] - 96s 5s/step - loss: 0.0461 - accuracy: 0.7572 - categorical_accuracy: 0.7572 - val_loss: 0.0443 - val_accuracy: 0.7678 - val_categorical_accuracy: 0.7678
# Epoch 12/15
# 20/20 [==============================] - 100s 5s/step - loss: 0.0402 - accuracy: 0.7659 - categorical_accuracy: 0.7659 - val_loss: 0.0408 - val_accuracy: 0.7729 - val_categorical_accuracy: 0.7729
# Epoch 13/15
# 20/20 [==============================] - 92s 5s/step - loss: 0.0384 - accuracy: 0.7766 - categorical_accuracy: 0.7766 - val_loss: 0.0376 - val_accuracy: 0.7769 - val_categorical_accuracy: 0.7769
# Epoch 14/15
# 20/20 [==============================] - 99s 5s/step - loss: 0.0373 - accuracy: 0.7774 - categorical_accuracy: 0.7774 - val_loss: 0.0360 - val_accuracy: 0.7753 - val_categorical_accuracy: 0.7753
# Epoch 15/15
# 20/20 [==============================] - 93s 5s/step - loss: 0.0361 - accuracy: 0.7763 - categorical_accuracy: 0.7763 - val_loss: 0.0377 - val_accuracy: 0.7774 - val_categorical_accuracy: 0.7774
# INFO:tensorflow:Assets written to: continuous_chosen_20_8_0.0001_2_4_mse_epochs=15__model_2/assets
# Model: "model_10"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_21 (InputLayer)           [(None, 256, 256, 2) 0
# __________________________________________________________________________________________________
# conv2d_158 (Conv2D)             (None, 256, 256, 8)  152         input_21[0][0]
# __________________________________________________________________________________________________
# conv2d_159 (Conv2D)             (None, 256, 256, 8)  584         conv2d_158[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_31 (MaxPooling2D) (None, 128, 128, 8)  0           conv2d_159[0][0]
# __________________________________________________________________________________________________
# conv2d_160 (Conv2D)             (None, 128, 128, 16) 1168        max_pooling2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_161 (Conv2D)             (None, 128, 128, 16) 2320        conv2d_160[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_32 (MaxPooling2D) (None, 64, 64, 16)   0           conv2d_161[0][0]
# __________________________________________________________________________________________________
# conv2d_162 (Conv2D)             (None, 64, 64, 32)   4640        max_pooling2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_163 (Conv2D)             (None, 64, 64, 32)   9248        conv2d_162[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_33 (MaxPooling2D) (None, 32, 32, 32)   0           conv2d_163[0][0]
# __________________________________________________________________________________________________
# conv2d_164 (Conv2D)             (None, 32, 32, 64)   18496       max_pooling2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_165 (Conv2D)             (None, 32, 32, 64)   36928       conv2d_164[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_34 (MaxPooling2D) (None, 16, 16, 64)   0           conv2d_165[0][0]
# __________________________________________________________________________________________________
# input_22 (InputLayer)           [(None, 16, 16, 14)] 0
# __________________________________________________________________________________________________
# concatenate_41 (Concatenate)    (None, 16, 16, 78)   0           max_pooling2d_34[0][0]
#                                                                  input_22[0][0]
# __________________________________________________________________________________________________
# conv2d_166 (Conv2D)             (None, 16, 16, 128)  89984       concatenate_41[0][0]
# __________________________________________________________________________________________________
# conv2d_167 (Conv2D)             (None, 16, 16, 128)  147584      conv2d_166[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_31 (UpSampling2D) (None, 32, 32, 128)  0           conv2d_167[0][0]
# __________________________________________________________________________________________________
# conv2d_168 (Conv2D)             (None, 32, 32, 64)   32832       up_sampling2d_31[0][0]
# __________________________________________________________________________________________________
# concatenate_42 (Concatenate)    (None, 32, 32, 128)  0           conv2d_165[0][0]
#                                                                  conv2d_168[0][0]
# __________________________________________________________________________________________________
# conv2d_169 (Conv2D)             (None, 32, 32, 64)   73792       concatenate_42[0][0]
# __________________________________________________________________________________________________
# conv2d_170 (Conv2D)             (None, 32, 32, 64)   36928       conv2d_169[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_32 (UpSampling2D) (None, 64, 64, 64)   0           conv2d_170[0][0]
# __________________________________________________________________________________________________
# conv2d_171 (Conv2D)             (None, 64, 64, 32)   8224        up_sampling2d_32[0][0]
# __________________________________________________________________________________________________
# concatenate_43 (Concatenate)    (None, 64, 64, 64)   0           conv2d_163[0][0]
#                                                                  conv2d_171[0][0]
# __________________________________________________________________________________________________
# conv2d_172 (Conv2D)             (None, 64, 64, 32)   18464       concatenate_43[0][0]
# __________________________________________________________________________________________________
# conv2d_173 (Conv2D)             (None, 64, 64, 32)   9248        conv2d_172[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_33 (UpSampling2D) (None, 128, 128, 32) 0           conv2d_173[0][0]
# __________________________________________________________________________________________________
# conv2d_174 (Conv2D)             (None, 128, 128, 16) 2064        up_sampling2d_33[0][0]
# __________________________________________________________________________________________________
# concatenate_44 (Concatenate)    (None, 128, 128, 32) 0           conv2d_161[0][0]
#                                                                  conv2d_174[0][0]
# __________________________________________________________________________________________________
# conv2d_175 (Conv2D)             (None, 128, 128, 16) 4624        concatenate_44[0][0]
# __________________________________________________________________________________________________
# conv2d_176 (Conv2D)             (None, 128, 128, 16) 2320        conv2d_175[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_34 (UpSampling2D) (None, 256, 256, 16) 0           conv2d_176[0][0]
# __________________________________________________________________________________________________
# conv2d_177 (Conv2D)             (None, 256, 256, 8)  520         up_sampling2d_34[0][0]
# __________________________________________________________________________________________________
# concatenate_45 (Concatenate)    (None, 256, 256, 16) 0           conv2d_159[0][0]
#                                                                  conv2d_177[0][0]
# __________________________________________________________________________________________________
# conv2d_178 (Conv2D)             (None, 256, 256, 8)  1160        concatenate_45[0][0]
# __________________________________________________________________________________________________
# conv2d_179 (Conv2D)             (None, 256, 256, 8)  584         conv2d_178[0][0]
# __________________________________________________________________________________________________
# conv2d_180 (Conv2D)             (None, 256, 256, 4)  292         conv2d_179[0][0]
# __________________________________________________________________________________________________
# conv2d_181 (Conv2D)             (None, 256, 256, 4)  20          conv2d_180[0][0]
# ==================================================================================================
# Total params: 502,176
# Trainable params: 502,176
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/15
# 20/20 [==============================] - 98s 5s/step - loss: 0.2390 - accuracy: 0.4333 - categorical_accuracy: 0.4333 - val_loss: 0.2250 - val_accuracy: 0.4609 - val_categorical_accuracy: 0.4609
# Epoch 2/15
# 20/20 [==============================] - 99s 5s/step - loss: 0.2146 - accuracy: 0.4463 - categorical_accuracy: 0.4463 - val_loss: 0.2138 - val_accuracy: 0.4555 - val_categorical_accuracy: 0.4555
# Epoch 3/15
# 20/20 [==============================] - 98s 5s/step - loss: 0.2104 - accuracy: 0.4467 - categorical_accuracy: 0.4467 - val_loss: 0.2151 - val_accuracy: 0.4566 - val_categorical_accuracy: 0.4566
# Epoch 4/15
# 20/20 [==============================] - 91s 5s/step - loss: 0.2045 - accuracy: 0.4425 - categorical_accuracy: 0.4425 - val_loss: 0.2050 - val_accuracy: 0.4511 - val_categorical_accuracy: 0.4511
# Epoch 5/15
# 20/20 [==============================] - 96s 5s/step - loss: 0.2015 - accuracy: 0.4436 - categorical_accuracy: 0.4436 - val_loss: 0.2019 - val_accuracy: 0.4542 - val_categorical_accuracy: 0.4542
# Epoch 6/15
# 20/20 [==============================] - 97s 5s/step - loss: 0.2035 - accuracy: 0.4405 - categorical_accuracy: 0.4405 - val_loss: 0.2081 - val_accuracy: 0.4429 - val_categorical_accuracy: 0.4429
# Epoch 7/15
# 20/20 [==============================] - 98s 5s/step - loss: 0.2004 - accuracy: 0.4441 - categorical_accuracy: 0.4441 - val_loss: 0.2081 - val_accuracy: 0.4565 - val_categorical_accuracy: 0.4565
# Epoch 8/15
# 20/20 [==============================] - 98s 5s/step - loss: 0.1997 - accuracy: 0.4425 - categorical_accuracy: 0.4425 - val_loss: 0.2056 - val_accuracy: 0.4572 - val_categorical_accuracy: 0.4572
# INFO:tensorflow:Assets written to: continuous_chosen_20_8_0.0001_2_4_mae_epochs=15__model_2/assets
# Model: "model_11"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_23 (InputLayer)           [(None, 256, 256, 2) 0
# __________________________________________________________________________________________________
# conv2d_182 (Conv2D)             (None, 256, 256, 8)  152         input_23[0][0]
# __________________________________________________________________________________________________
# conv2d_183 (Conv2D)             (None, 256, 256, 8)  584         conv2d_182[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_35 (MaxPooling2D) (None, 128, 128, 8)  0           conv2d_183[0][0]
# __________________________________________________________________________________________________
# conv2d_184 (Conv2D)             (None, 128, 128, 16) 1168        max_pooling2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_185 (Conv2D)             (None, 128, 128, 16) 2320        conv2d_184[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_36 (MaxPooling2D) (None, 64, 64, 16)   0           conv2d_185[0][0]
# __________________________________________________________________________________________________
# conv2d_186 (Conv2D)             (None, 64, 64, 32)   4640        max_pooling2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_187 (Conv2D)             (None, 64, 64, 32)   9248        conv2d_186[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_37 (MaxPooling2D) (None, 32, 32, 32)   0           conv2d_187[0][0]
# __________________________________________________________________________________________________
# conv2d_188 (Conv2D)             (None, 32, 32, 64)   18496       max_pooling2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_189 (Conv2D)             (None, 32, 32, 64)   36928       conv2d_188[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_38 (MaxPooling2D) (None, 16, 16, 64)   0           conv2d_189[0][0]
# __________________________________________________________________________________________________
# input_24 (InputLayer)           [(None, 16, 16, 14)] 0
# __________________________________________________________________________________________________
# concatenate_46 (Concatenate)    (None, 16, 16, 78)   0           max_pooling2d_38[0][0]
#                                                                  input_24[0][0]
# __________________________________________________________________________________________________
# conv2d_190 (Conv2D)             (None, 16, 16, 128)  89984       concatenate_46[0][0]
# __________________________________________________________________________________________________
# conv2d_191 (Conv2D)             (None, 16, 16, 128)  147584      conv2d_190[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_35 (UpSampling2D) (None, 32, 32, 128)  0           conv2d_191[0][0]
# __________________________________________________________________________________________________
# conv2d_192 (Conv2D)             (None, 32, 32, 64)   32832       up_sampling2d_35[0][0]
# __________________________________________________________________________________________________
# concatenate_47 (Concatenate)    (None, 32, 32, 128)  0           conv2d_189[0][0]
#                                                                  conv2d_192[0][0]
# __________________________________________________________________________________________________
# conv2d_193 (Conv2D)             (None, 32, 32, 64)   73792       concatenate_47[0][0]
# __________________________________________________________________________________________________
# conv2d_194 (Conv2D)             (None, 32, 32, 64)   36928       conv2d_193[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_36 (UpSampling2D) (None, 64, 64, 64)   0           conv2d_194[0][0]
# __________________________________________________________________________________________________
# conv2d_195 (Conv2D)             (None, 64, 64, 32)   8224        up_sampling2d_36[0][0]
# __________________________________________________________________________________________________
# concatenate_48 (Concatenate)    (None, 64, 64, 64)   0           conv2d_187[0][0]
#                                                                  conv2d_195[0][0]
# __________________________________________________________________________________________________
# conv2d_196 (Conv2D)             (None, 64, 64, 32)   18464       concatenate_48[0][0]
# __________________________________________________________________________________________________
# conv2d_197 (Conv2D)             (None, 64, 64, 32)   9248        conv2d_196[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_37 (UpSampling2D) (None, 128, 128, 32) 0           conv2d_197[0][0]
# __________________________________________________________________________________________________
# conv2d_198 (Conv2D)             (None, 128, 128, 16) 2064        up_sampling2d_37[0][0]
# __________________________________________________________________________________________________
# concatenate_49 (Concatenate)    (None, 128, 128, 32) 0           conv2d_185[0][0]
#                                                                  conv2d_198[0][0]
# __________________________________________________________________________________________________
# conv2d_199 (Conv2D)             (None, 128, 128, 16) 4624        concatenate_49[0][0]
# __________________________________________________________________________________________________
# conv2d_200 (Conv2D)             (None, 128, 128, 16) 2320        conv2d_199[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_38 (UpSampling2D) (None, 256, 256, 16) 0           conv2d_200[0][0]
# __________________________________________________________________________________________________
# conv2d_201 (Conv2D)             (None, 256, 256, 8)  520         up_sampling2d_38[0][0]
# __________________________________________________________________________________________________
# concatenate_50 (Concatenate)    (None, 256, 256, 16) 0           conv2d_183[0][0]
#                                                                  conv2d_201[0][0]
# __________________________________________________________________________________________________
# conv2d_202 (Conv2D)             (None, 256, 256, 8)  1160        concatenate_50[0][0]
# __________________________________________________________________________________________________
# conv2d_203 (Conv2D)             (None, 256, 256, 8)  584         conv2d_202[0][0]
# __________________________________________________________________________________________________
# conv2d_204 (Conv2D)             (None, 256, 256, 4)  292         conv2d_203[0][0]
# __________________________________________________________________________________________________
# conv2d_205 (Conv2D)             (None, 256, 256, 4)  20          conv2d_204[0][0]
# ==================================================================================================
# Total params: 502,176
# Trainable params: 502,176
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/15
# 20/20 [==============================] - 92s 5s/step - loss: 2.9306 - accuracy: 0.1525 - categorical_accuracy: 0.1525 - val_loss: 1.8797 - val_accuracy: 0.1362 - val_categorical_accuracy: 0.1362
# Epoch 2/15
# 20/20 [==============================] - 96s 5s/step - loss: 1.6051 - accuracy: 0.1175 - categorical_accuracy: 0.1175 - val_loss: 1.5034 - val_accuracy: 0.0837 - val_categorical_accuracy: 0.0837
# Epoch 3/15
# 20/20 [==============================] - 98s 5s/step - loss: 1.4455 - accuracy: 0.1398 - categorical_accuracy: 0.1398 - val_loss: 1.3781 - val_accuracy: 0.1881 - val_categorical_accuracy: 0.1881
# Epoch 4/15
# 20/20 [==============================] - 98s 5s/step - loss: 1.3452 - accuracy: 0.2284 - categorical_accuracy: 0.2284 - val_loss: 1.3027 - val_accuracy: 0.2822 - val_categorical_accuracy: 0.2822
# Epoch 5/15
# 20/20 [==============================] - 90s 5s/step - loss: 1.2855 - accuracy: 0.2837 - categorical_accuracy: 0.2837 - val_loss: 1.2604 - val_accuracy: 0.3088 - val_categorical_accuracy: 0.3088
# Epoch 6/15
# 20/20 [==============================] - 97s 5s/step - loss: 1.2466 - accuracy: 0.3131 - categorical_accuracy: 0.3131 - val_loss: 1.2193 - val_accuracy: 0.3302 - val_categorical_accuracy: 0.3302
# Epoch 7/15
# 20/20 [==============================] - 98s 5s/step - loss: 1.1974 - accuracy: 0.3435 - categorical_accuracy: 0.3435 - val_loss: 1.1687 - val_accuracy: 0.3783 - val_categorical_accuracy: 0.3783
# Epoch 8/15
# 20/20 [==============================] - 98s 5s/step - loss: 1.1363 - accuracy: 0.3953 - categorical_accuracy: 0.3953 - val_loss: 1.0895 - val_accuracy: 0.4333 - val_categorical_accuracy: 0.4333
# Epoch 9/15
# 20/20 [==============================] - 94s 5s/step - loss: 1.0651 - accuracy: 0.4585 - categorical_accuracy: 0.4585 - val_loss: 1.0388 - val_accuracy: 0.5080 - val_categorical_accuracy: 0.5080
# Epoch 10/15
# 20/20 [==============================] - 95s 5s/step - loss: 1.0278 - accuracy: 0.5074 - categorical_accuracy: 0.5074 - val_loss: 1.0149 - val_accuracy: 0.5361 - val_categorical_accuracy: 0.5361
# Epoch 11/15
# 20/20 [==============================] - 113s 6s/step - loss: 1.0098 - accuracy: 0.5294 - categorical_accuracy: 0.5294 - val_loss: 0.9959 - val_accuracy: 0.5641 - val_categorical_accuracy: 0.5641
# Epoch 12/15
# 20/20 [==============================] - 101s 5s/step - loss: 0.9901 - accuracy: 0.5593 - categorical_accuracy: 0.5593 - val_loss: 0.9758 - val_accuracy: 0.5812 - val_categorical_accuracy: 0.5812
# Epoch 13/15
# 20/20 [==============================] - 98s 5s/step - loss: 0.9702 - accuracy: 0.5865 - categorical_accuracy: 0.5865 - val_loss: 0.9496 - val_accuracy: 0.6146 - val_categorical_accuracy: 0.6146
# Epoch 14/15
# 20/20 [==============================] - 125s 6s/step - loss: 0.9430 - accuracy: 0.6211 - categorical_accuracy: 0.6211 - val_loss: 0.9222 - val_accuracy: 0.6554 - val_categorical_accuracy: 0.6554
# Epoch 15/15
# 20/20 [==============================] - 169s 9s/step - loss: 0.9132 - accuracy: 0.6635 - categorical_accuracy: 0.6635 - val_loss: 0.8917 - val_accuracy: 0.7033 - val_categorical_accuracy: 0.7033
# INFO:tensorflow:Assets written to: continuous_chosen_20_8_0.0001_2_4_categorical_crossentropy_epochs=15__model_2/assets
# Model: "model_12"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_25 (InputLayer)           [(None, 256, 256, 2) 0
# __________________________________________________________________________________________________
# conv2d_206 (Conv2D)             (None, 256, 256, 8)  152         input_25[0][0]
# __________________________________________________________________________________________________
# conv2d_207 (Conv2D)             (None, 256, 256, 8)  584         conv2d_206[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_39 (MaxPooling2D) (None, 128, 128, 8)  0           conv2d_207[0][0]
# __________________________________________________________________________________________________
# conv2d_208 (Conv2D)             (None, 128, 128, 16) 1168        max_pooling2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_209 (Conv2D)             (None, 128, 128, 16) 2320        conv2d_208[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_40 (MaxPooling2D) (None, 64, 64, 16)   0           conv2d_209[0][0]
# __________________________________________________________________________________________________
# conv2d_210 (Conv2D)             (None, 64, 64, 32)   4640        max_pooling2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_211 (Conv2D)             (None, 64, 64, 32)   9248        conv2d_210[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_41 (MaxPooling2D) (None, 32, 32, 32)   0           conv2d_211[0][0]
# __________________________________________________________________________________________________
# conv2d_212 (Conv2D)             (None, 32, 32, 64)   18496       max_pooling2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_213 (Conv2D)             (None, 32, 32, 64)   36928       conv2d_212[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_42 (MaxPooling2D) (None, 16, 16, 64)   0           conv2d_213[0][0]
# __________________________________________________________________________________________________
# input_26 (InputLayer)           [(None, 16, 16, 14)] 0
# __________________________________________________________________________________________________
# concatenate_51 (Concatenate)    (None, 16, 16, 78)   0           max_pooling2d_42[0][0]
#                                                                  input_26[0][0]
# __________________________________________________________________________________________________
# conv2d_214 (Conv2D)             (None, 16, 16, 128)  89984       concatenate_51[0][0]
# __________________________________________________________________________________________________
# conv2d_215 (Conv2D)             (None, 16, 16, 128)  147584      conv2d_214[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_39 (UpSampling2D) (None, 32, 32, 128)  0           conv2d_215[0][0]
# __________________________________________________________________________________________________
# conv2d_216 (Conv2D)             (None, 32, 32, 64)   32832       up_sampling2d_39[0][0]
# __________________________________________________________________________________________________
# concatenate_52 (Concatenate)    (None, 32, 32, 128)  0           conv2d_213[0][0]
#                                                                  conv2d_216[0][0]
# __________________________________________________________________________________________________
# conv2d_217 (Conv2D)             (None, 32, 32, 64)   73792       concatenate_52[0][0]
# __________________________________________________________________________________________________
# conv2d_218 (Conv2D)             (None, 32, 32, 64)   36928       conv2d_217[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_40 (UpSampling2D) (None, 64, 64, 64)   0           conv2d_218[0][0]
# __________________________________________________________________________________________________
# conv2d_219 (Conv2D)             (None, 64, 64, 32)   8224        up_sampling2d_40[0][0]
# __________________________________________________________________________________________________
# concatenate_53 (Concatenate)    (None, 64, 64, 64)   0           conv2d_211[0][0]
#                                                                  conv2d_219[0][0]
# __________________________________________________________________________________________________
# conv2d_220 (Conv2D)             (None, 64, 64, 32)   18464       concatenate_53[0][0]
# __________________________________________________________________________________________________
# conv2d_221 (Conv2D)             (None, 64, 64, 32)   9248        conv2d_220[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_41 (UpSampling2D) (None, 128, 128, 32) 0           conv2d_221[0][0]
# __________________________________________________________________________________________________
# conv2d_222 (Conv2D)             (None, 128, 128, 16) 2064        up_sampling2d_41[0][0]
# __________________________________________________________________________________________________
# concatenate_54 (Concatenate)    (None, 128, 128, 32) 0           conv2d_209[0][0]
#                                                                  conv2d_222[0][0]
# __________________________________________________________________________________________________
# conv2d_223 (Conv2D)             (None, 128, 128, 16) 4624        concatenate_54[0][0]
# __________________________________________________________________________________________________
# conv2d_224 (Conv2D)             (None, 128, 128, 16) 2320        conv2d_223[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_42 (UpSampling2D) (None, 256, 256, 16) 0           conv2d_224[0][0]
# __________________________________________________________________________________________________
# conv2d_225 (Conv2D)             (None, 256, 256, 8)  520         up_sampling2d_42[0][0]
# __________________________________________________________________________________________________
# concatenate_55 (Concatenate)    (None, 256, 256, 16) 0           conv2d_207[0][0]
#                                                                  conv2d_225[0][0]
# __________________________________________________________________________________________________
# conv2d_226 (Conv2D)             (None, 256, 256, 8)  1160        concatenate_55[0][0]
# __________________________________________________________________________________________________
# conv2d_227 (Conv2D)             (None, 256, 256, 8)  584         conv2d_226[0][0]
# __________________________________________________________________________________________________
# conv2d_228 (Conv2D)             (None, 256, 256, 4)  292         conv2d_227[0][0]
# __________________________________________________________________________________________________
# conv2d_229 (Conv2D)             (None, 256, 256, 4)  20          conv2d_228[0][0]
# ==================================================================================================
# Total params: 502,176
# Trainable params: 502,176
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/15
# 20/20 [==============================] - 140s 7s/step - loss: 0.2670 - accuracy: 0.4252 - categorical_accuracy: 0.4252 - val_loss: 0.2602 - val_accuracy: 0.4403 - val_categorical_accuracy: 0.4403
# Epoch 2/15
# 20/20 [==============================] - 154s 8s/step - loss: 0.2433 - accuracy: 0.4252 - categorical_accuracy: 0.4252 - val_loss: 0.2146 - val_accuracy: 0.4409 - val_categorical_accuracy: 0.4409
# Epoch 3/15
# 20/20 [==============================] - 214s 11s/step - loss: 0.2083 - accuracy: 0.4253 - categorical_accuracy: 0.4253 - val_loss: 0.1995 - val_accuracy: 0.4406 - val_categorical_accuracy: 0.4406
# Epoch 4/15
# 20/20 [==============================] - 119s 6s/step - loss: 0.1962 - accuracy: 0.4251 - categorical_accuracy: 0.4251 - val_loss: 0.1918 - val_accuracy: 0.4403 - val_categorical_accuracy: 0.4403
# Epoch 5/15
# 20/20 [==============================] - 158s 8s/step - loss: 0.1879 - accuracy: 0.4255 - categorical_accuracy: 0.4255 - val_loss: 0.1877 - val_accuracy: 0.4417 - val_categorical_accuracy: 0.4417
# Epoch 6/15
# 20/20 [==============================] - 149s 8s/step - loss: 0.1810 - accuracy: 0.4268 - categorical_accuracy: 0.4268 - val_loss: 0.1779 - val_accuracy: 0.4422 - val_categorical_accuracy: 0.4422
# Epoch 7/15
# 20/20 [==============================] - 172s 9s/step - loss: 0.1826 - accuracy: 0.4298 - categorical_accuracy: 0.4298 - val_loss: 0.1879 - val_accuracy: 0.4646 - val_categorical_accuracy: 0.4646
# Epoch 8/15
# 20/20 [==============================] - 147s 7s/step - loss: 0.1770 - accuracy: 0.6027 - categorical_accuracy: 0.6027 - val_loss: 0.1799 - val_accuracy: 0.7656 - val_categorical_accuracy: 0.7656
# Epoch 9/15
# 20/20 [==============================] - 171s 9s/step - loss: 0.1697 - accuracy: 0.7785 - categorical_accuracy: 0.7785 - val_loss: 0.1677 - val_accuracy: 0.7769 - val_categorical_accuracy: 0.7769
# Epoch 10/15
# 20/20 [==============================] - 126s 6s/step - loss: 0.1620 - accuracy: 0.7871 - categorical_accuracy: 0.7871 - val_loss: 0.1613 - val_accuracy: 0.7809 - val_categorical_accuracy: 0.7809
# Epoch 11/15
# 20/20 [==============================] - 162s 8s/step - loss: 0.1563 - accuracy: 0.7836 - categorical_accuracy: 0.7836 - val_loss: 0.1563 - val_accuracy: 0.7926 - val_categorical_accuracy: 0.7926
# Epoch 12/15
# 20/20 [==============================] - 148s 8s/step - loss: 0.1513 - accuracy: 0.7866 - categorical_accuracy: 0.7866 - val_loss: 0.1557 - val_accuracy: 0.7916 - val_categorical_accuracy: 0.7916
# Epoch 13/15
# 20/20 [==============================] - 146s 8s/step - loss: 0.1450 - accuracy: 0.7865 - categorical_accuracy: 0.7865 - val_loss: 0.1453 - val_accuracy: 0.7830 - val_categorical_accuracy: 0.7830
# Epoch 14/15
# 20/20 [==============================] - 141s 7s/step - loss: 0.1415 - accuracy: 0.7898 - categorical_accuracy: 0.7898 - val_loss: 0.1444 - val_accuracy: 0.7638 - val_categorical_accuracy: 0.7638
# Epoch 15/15
# 20/20 [==============================] - 172s 9s/step - loss: 0.1413 - accuracy: 0.7837 - categorical_accuracy: 0.7837 - val_loss: 0.1436 - val_accuracy: 0.7793 - val_categorical_accuracy: 0.7793
# INFO:tensorflow:Assets written to: continuous_chosen_20_8_0.0001_2_4_<function weighted_categorical_crossentropy.<locals>.loss at 0x7f776129c598>_epochs=15__model_2/assets
